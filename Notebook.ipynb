# %%
import pandas as pd
import os

from src.CornersModelPerformancePlotter import (
    CornersModelPerformancePlotter as CMPPlotter,
)

# %%
# Get data
DATA_LINK = (
    "https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json"
)
DATA_FILENAME = "data/deviation.json"
PLOTS_FOLDER = "plots"

if not os.path.exists(DATA_FILENAME):
    df = pd.read_json(DATA_LINK)
    df.to_json(DATA_FILENAME)  # Save data locally

df = pd.read_json(DATA_FILENAME)
df.head()
# Out:
#            name  gt_corners  rb_corners       mean        max       min  \
# 0  Schlafzimmer           4           4   3.956313   8.562939  0.274574
# 1         Küche           4           4  23.019122  52.605437  0.724299
# 2      Bathroom           4           4   1.013833   1.950322  0.301673
# 3  Lounge/Diner           8           8   3.832620  18.236935  0.173307
# 4    Essbereich           4           4   8.017758  15.642853  0.762948
#
#    floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  ceiling_min
# 0    3.987864   8.562939   0.274574      3.924762     8.501885     0.331494
# 1    1.253103   1.897612   0.724299     44.785141    52.605437    36.880814
# 2    0.659138   1.318714   0.301673      1.368528     1.950322     0.878106
# 3    3.600083  15.041431   0.173307      4.065157    18.236935     0.253457
# 4    7.819446  15.399635   0.762948      8.216069    15.642853     0.909029

# %%
# Plot data
plotter = CMPPlotter(save_dir="plots", darkgrid=True)
plotter.draw_plots(df)
# Out:
# ['plots/confusion_matrices.png',
#  'plots/deviation_statistics_all.png',
#  'plots/deviation_statistics_floor.png',
#  'plots/deviation_statistics_mean.png',
#  'plots/best_worst_predictions.png']

# %% [markdown]
# # Results
#
# 1. Model has detected all corners on the images.
# 2. Model performance is worse on ceiling points than on floor points.
# 3. The worst performance was on Texas Home Common Area 6, while the best was on 3rd Floor Bathroom.

# %%
#
